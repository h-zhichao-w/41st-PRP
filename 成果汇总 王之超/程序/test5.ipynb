# %%
import numpy as np
import pandas as pd
import folium
from RMM import *

# 加载待匹配数据
DF = pd.read_csv('BL_0425.csv')
RawLat = np.array(DF.iloc[:, 2])
RawLog = np.array(DF.iloc[:, 3])

# city_map = folium.Map(location=[np.mean(RawLat), np.mean(RawLog)], zoom_start=12)
# for i in range(RawLog.shape[0]):
#     folium.Circle(
#         radius=5,
#         location=(RawLat[i], RawLog[i]),
#         # 无需匹配点，使用绿色
#         color='#33cc33',
#         fill=True,
#         fill_color='#33cc33'
#     ).add_to(city_map)
# city_map.save('show.html')

# 加载路网数据
# 加载路网数据
root = 'train/2021-01-05-US-MTV-1/'
filename = ['GooglePixel4/', 'GooglePixel4XL/', 'XiaomiMi8/']
DF = []
for fn in filename:
    path = root + fn + 'ground_truth.csv'
    DF.append(pd.read_csv(path))

Road = pd.concat([DF[0], DF[1], DF[2]]).iloc[:, 2:4]
Road = Road.drop_duplicates().sort_values(by='LatitudeDegrees')
# print(Road )
RoadLat = np.array(Road.iloc[:, 0])
RoadLog = np.array(Road.iloc[:, 1])


out_of_range = []
good = []
to_be_matched = []
lists = []

# %%
# 对待匹配数据每个点进行查找是否附近在道路附近
for i in range(RawLat.shape[0]):
    for A in range(5, 43, 5):
        flag, index = IsTooLarge(RoadLat, RoadLog, RawLat[i], RawLog[i], A*1e-5)
        if flag and A == 42:
            print('点', i+1, '45米内无道路数据点')
            out_of_range.append(i)
            break
        elif not flag and A <= 5:
            print('点', i+1, '在道路范围5米内')
            good.append(i)
            break
        elif not flag and A > 5:
            print('点', i+1, '距离道路在5米以上')
            to_be_matched.append(i)
            lists.append(index)
            break
        else: continue

city_map = folium.Map(location=[np.mean(RawLat), np.mean(RawLog)], zoom_start=12)
layer_road = folium.FeatureGroup(name='Road Data')

for i in range(RoadLog.shape[0]):
    folium.Circle(
        radius=5,
        location=(RoadLat[i], RoadLog[i]),
        # 道路点使用蓝色
        color='#0066ff',
        fill=True,
        fill_color='#0066ff'
    ).add_to(layer_road)
# Out:
# 点 1 距离道路在5米以上
# 点 2 距离道路在5米以上
# 点 3 距离道路在5米以上
# 点 4 距离道路在5米以上
# 点 5 距离道路在5米以上
# 点 6 距离道路在5米以上
# 点 7 距离道路在5米以上
# 点 8 距离道路在5米以上
# 点 9 距离道路在5米以上
# 点 10 距离道路在5米以上
# 点 11 距离道路在5米以上
# 点 12 距离道路在5米以上
# 点 13 距离道路在5米以上
# 点 14 距离道路在5米以上
# 点 15 距离道路在5米以上
# 点 16 距离道路在5米以上
# 点 17 距离道路在5米以上
# 点 18 距离道路在5米以上
# 点 19 距离道路在5米以上
# 点 20 距离道路在5米以上
# 点 21 距离道路在5米以上
# 点 22 距离道路在5米以上
# 点 23 距离道路在5米以上
# 点 24 距离道路在5米以上
# 点 25 距离道路在5米以上
# 点 26 距离道路在5米以上
# 点 27 距离道路在5米以上
# 点 28 距离道路在5米以上
# 点 29 距离道路在5米以上
# 点 30 距离道路在5米以上
# 点 1190 在道路范围5米内
# 点 1191 在道路范围5米内
# 点 1192 在道路范围5米内
# 点 1193 在道路范围5米内
# 点 1194 在道路范围5米内
# 点 1195 在道路范围5米内
# 点 1196 在道路范围5米内
# 点 1197 在道路范围5米内
# 点 1198 在道路范围5米内
# 点 1199 在道路范围5米内
# 点 1200 在道路范围5米内
# 点 1201 在道路范围5米内
# 点 1202 在道路范围5米内
# 点 1203 在道路范围5米内
# 点 1204 在道路范围5米内
# 点 1205 在道路范围5米内
# 点 1206 在道路范围5米内
# 点 1207 在道路范围5米内
# 点 1208 在道路范围5米内
# 点 1209 在道路范围5米内
# 点 1210 在道路范围5米内
# 点 1211 在道路范围5米内
# 点 1212 在道路范围5米内
# 点 1213 在道路范围5米内
# 点 1214 在道路范围5米内
# 点 1215 在道路范围5米内
# 点 1216 在道路范围5米内
# 点 1217 在道路范围5米内
# 点 1218 在道路范围5米内
# 点 1219 在道路范围5米内
# 点 1220 在道路范围5米内
# 点 1221 在道路范围5米内
# 点 1222 在道路范围5米内
# 点 1223 在道路范围5米内
# 点 1224 在道路范围5米内
# 点 1225 在道路范围5米内
# 点 1226 在道路范围5米内
# 点 1227 在道路范围5米内
# 点 1228 在道路范围5米内
# 点 1229 在道路范围5米内
# 点 1230 在道路范围5米内
# 点 1231 在道路范围5米内
# 点 1232 在道路范围5米内
# 点 1233 在道路范围5米内
# 点 1234 在道路范围5米内
# 点 1235 在道路范围5米内
# 点 1236 在道路范围5米内
# 点 1237 在道路范围5米内
# 点 1238 在道路范围5米内
# 点 1239 在道路范围5米内
# 点 1240 在道路范围5米内
# 点 1241 在道路范围5米内
# 点 1242 在道路范围5米内
# 点 1243 距离道路在5米以上
# 点 1244 距离道路在5米以上
# 点 1245 距离道路在5米以上
# 点 1246 距离道路在5米以上
# 点 1247 距离道路在5米以上
# 点 1248 距离道路在5米以上
# 点 1249 距离道路在5米以上
# 点 1250 距离道路在5米以上
# 点 1251 距离道路在5米以上
# 点 1252 距离道路在5米以上
# 点 1253 距离道路在5米以上
# 点 1254 距离道路在5米以上
# 点 1255 距离道路在5米以上
# 点 1256 距离道路在5米以上
# 点 1257 距离道路在5米以上
# 点 1258 距离道路在5米以上
# 点 1259 距离道路在5米以上
# 点 1260 距离道路在5米以上
# 点 1261 距离道路在5米以上
# 点 1262 距离道路在5米以上
# 点 1263 距离道路在5米以上
# 点 1264 距离道路在5米以上
# 点 1265 距离道路在5米以上

# %%
# 将各类信息再次显示在地图上
layer_unmatched = folium.FeatureGroup(name='Raw Data')

for i in good:
    folium.Circle(
        radius=5,
        location=(RawLat[i], RawLog[i]),
        # 无需匹配点，使用绿色
        color='#33cc33',
        fill=True,
        fill_color='#33cc33'
    ).add_to(layer_unmatched)

for i in out_of_range:
    folium.Circle(
        radius=5,
        location=(RawLat[i], RawLog[i]),
        # 异常点使用黑色
        color='#000000',
        fill=True,
        fill_color='#000000'
    ).add_to(layer_unmatched)

for i in to_be_matched:
    folium.Circle(
        radius=5,
        location=(RawLat[i], RawLog[i]),
        # 待匹配点使用红色
        color='#ff0000',
        fill=True,
        fill_color='#ff0000'
    ).add_to(layer_unmatched)

# %%
layer_matched = folium.FeatureGroup(name='Matched Data')
NewLat = []
NewLog = []
print(len(to_be_matched))
for i in range(len(to_be_matched)):
    index = to_be_matched[i]
    road_points = lists[i]
    if len(road_points) > 1:
        try:
            k = (RawLat[index + 1] - RawLat[index - 1]) / (RawLog[index + 1] - RawLog[index - 1])
        except ZeroDivisionError:
            k = (RawLog[index + 1] - RawLog[index - 1]) / (RawLat[index + 1] - RawLat[index - 1])
        except IndexError:
            NewSinLat = 0
            NewSinLog = 0
            num = 0
            for j in road_points:
                NewSinLat += (1. / dis(RawLog[index], RawLat[index], RoadLog[j], RoadLat[j])) * RoadLat[j]
                NewSinLog += (1. / dis(RawLog[index], RawLat[index], RoadLog[j], RoadLat[j])) * RoadLog[j]
                num += 1. / dis(RawLog[index], RawLat[index], RoadLog[j], RoadLat[j])

            NewSinLat /= num
            NewSinLog /= num
            NewLat.append(NewSinLat)
            NewLog.append(NewSinLog)
            continue
        j = 0
        while j < len(road_points):
            try:
                k_road = (RoadLat[road_points[j + 1]] - RoadLat[road_points[j]]) / (RoadLog[road_points[j + 1]] - RoadLog[road_points[j]])
            except IndexError:
                if len(road_points) == 1:
                    road_points = []
                    break
                else: break
            except ZeroDivisionError:
                k_road = (RoadLog[road_points[j + 1]] - RoadLog[road_points[j]]) / (RoadLat[road_points[j + 1]] - RoadLat[road_points[j]])

            if abs(k_road - k) <= 0.05:
                j += 1
            else:
                road_points.pop(j)
                # j -= 1
        if len(road_points) != 0:
            NewSinLat = 0
            NewSinLog = 0
            num = 0
            for j in road_points:
                NewSinLat += (1. / dis(RawLog[index], RawLat[index], RoadLog[j], RoadLat[j])) * RoadLat[j]
                NewSinLog += (1. / dis(RawLog[index], RawLat[index], RoadLog[j], RoadLat[j])) * RoadLog[j]
                num += 1. / dis(RawLog[index], RawLat[index], RoadLog[j], RoadLat[j])

            NewSinLat /= num
            NewSinLog /= num
            NewLat.append(NewSinLat)
            NewLog.append(NewSinLog)
    elif len(road_points) == 0:
        pass
    else:
        NewLat.append(RoadLat[road_points[0]])
        NewLog.append(RoadLog[road_points[0]])

print(len(NewLat))

city_map = folium.Map(location=[np.mean(RawLat), np.mean(RawLog)], zoom_start=12)
for i in to_be_matched:
    folium.Circle(
        radius=5,
        location=(RawLat[i], RawLog[i]),
        # 待匹配点使用红色
        color='#ff0000',
        fill=True,
        fill_color='#ff0000'
    ).add_to(layer_matched)
for i in range(len(NewLat)):
    folium.Circle(
        radius=5,
        location=(NewLat[i], NewLog[i]),
        # 匹配后点使用紫红色
        color='#cc33cc',
        fill=True,
        fill_color='#cc33cc'
    ).add_to(layer_matched)
# Out:
# 380
# 380

# %%
city_map.add_child(layer_road)
city_map.add_child(layer_unmatched)
city_map.add_child(layer_matched)
folium.LayerControl().add_to(city_map)
city_map.save('test6.html')

# %%
for i in range(len(to_be_matched)):
    index = to_be_matched[i]
    RawLat[index] = NewLat[i]
    RawLog[index] = NewLog[i]

df = pd.DataFrame({'LatitudeDegrees': RawLat, 'LongitudeDegrees': RawLog})
df.to_csv('0105.csv')
