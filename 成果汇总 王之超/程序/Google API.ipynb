# %%
import requests

API = 'AIzaSyBKsUpcQJNrIut90IjVxUBYzutazuc0d4E'
url = "https://roads.googleapis.com/v1/snapToRoads?path=-35.27801%2C149.12958%7C-35.28032%2C149.12907%7C-35.28099%2C149.12929%7C-35.28144%2C149.12984%7C-35.28194%2C149.13003%7C-35.28282%2C149.12956%7C-35.28302%2C149.12881%7C-35.28473%2C149.12836&interpolate=true&key={}".format(API)

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {
#   "error": {
#     "code": 404,
#     "message": "Requested entity was not found.",
#     "status": "NOT_FOUND"
#   }
# }

# %%
import requests

API = 'AIzaSyBKsUpcQJNrIut90IjVxUBYzutazuc0d4E'
url = "https://roads.googleapis.com/v1/snapToRoads?path=-35.27801%2C149.12958%7C-35.28032%2C149.12907%7C-35.28099%2C149.12929%7C-35.28144%2C149.12984%7C-35.28194%2C149.13003%7C-35.28282%2C149.12956%7C-35.28302%2C149.12881%7C-35.28473%2C149.12836&interpolate=false&key={}".format(API)

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {
#   "error": {
#     "code": 404,
#     "message": "Requested entity was not found.",
#     "status": "NOT_FOUND"
#   }
# }

# %%
import numpy as np

sp = {
  "snappedPoints":
    [
      {
        "location":
          { "latitude": -35.27800489993019, "longitude": 149.129531998742 },
        "originalIndex": 0,
        "placeId": "ChIJr_xl0GdNFmsRsUtUbW7qABM",
      },
      {
        "location":
          { "latitude": -35.2784195, "longitude": 149.12946589999999 },
        "placeId": "ChIJr_xl0GdNFmsRsUtUbW7qABM",
      },
      {
        "location":
          { "latitude": -35.2784195, "longitude": 149.12946589999999 },
        "placeId": "ChIJ6aXGemhNFmsRZE_zHqhmrG4",
      },
      {
        "location":
          { "latitude": -35.2792731, "longitude": 149.12933809999998 },
        "placeId": "ChIJ6aXGemhNFmsRZE_zHqhmrG4",
      },
      {
        "location":
          { "latitude": -35.2792731, "longitude": 149.12933809999998 },
        "placeId": "ChIJTcTdZ2hNFmsRXokM4mWCWfk",
      },
      {
        "location": { "latitude": -35.279557, "longitude": 149.1292973 },
        "placeId": "ChIJTcTdZ2hNFmsRXokM4mWCWfk",
      },
      {
        "location": { "latitude": -35.279557, "longitude": 149.1292973 },
        "placeId": "ChIJiUfNQmhNFmsRSsAI-1m6y1g",
      },
      {
        "location":
          { "latitude": -35.279610999999996, "longitude": 149.1292889 },
        "placeId": "ChIJiUfNQmhNFmsRSsAI-1m6y1g",
      },
      {
        "location": { "latitude": -35.2796484, "longitude": 149.1292791 },
        "placeId": "ChIJiUfNQmhNFmsRSsAI-1m6y1g",
      },
      {
        "location": { "latitude": -35.2796484, "longitude": 149.1292791 },
        "placeId": "ChIJ_RyFQ2hNFmsRoHJAbW7qABM",
      },
      {
        "location":
          { "latitude": -35.279947299999996, "longitude": 149.1291894 },
        "placeId": "ChIJ_RyFQ2hNFmsRoHJAbW7qABM",
      },
      {
        "location":
},
        "placeId": "ChIJWSb8ImpNFmsRp_4JAxJFE1A",
      },
      {
        "location": { "latitude": -35.2839978, "longitude": 149.1284682 },
        "placeId": "ChIJWSb8ImpNFmsRp_4JAxJFE1A",
      },
      {
        "location":
          { "latitude": -35.2840205, "longitude": 149.12846779999998 },
        "placeId": "ChIJWSb8ImpNFmsRp_4JAxJFE1A",
      },
      {
        "location":
          { "latitude": -35.2840205, "longitude": 149.12846779999998 },
        "placeId": "ChIJZe8tFWpNFmsR4brZ1vldk2E",
      },
      {
        "location":
          { "latitude": -35.2840524, "longitude": 149.12845969999998 },
        "placeId": "ChIJZe8tFWpNFmsR4brZ1vldk2E",
      },
      {
        "location":
          { "latitude": -35.284341500000004, "longitude": 149.1284124 },
        "placeId": "ChIJZe8tFWpNFmsR4brZ1vldk2E",
      },
      {
        "location": { "latitude": -35.2843875, "longitude": 149.1284034 },
        "placeId": "ChIJZe8tFWpNFmsR4brZ1vldk2E",
      },
      {
        "location": { "latitude": -35.2843875, "longitude": 149.1284034 },
        "placeId": "ChIJVx7Ta2pNFmsRx9OI9CnN5tI",
      },
      {
        "location": { "latitude": -35.2845916, "longitude": 149.1283726 },
        "placeId": "ChIJVx7Ta2pNFmsRx9OI9CnN5tI",
      },
      {
        "location": { "latitude": -35.2845916, "longitude": 149.1283726 },
        "placeId": "ChIJtWxAZmpNFmsRlbUCkc6VtnA",
      },
      {
        "location":
          { "latitude": -35.28459730000001, "longitude": 149.1283703 },
        "placeId": "ChIJtWxAZmpNFmsRlbUCkc6VtnA",
      },
      {
        "location":
          { "latitude": -35.284728747199374, "longitude": 149.12834860726772 },
        "originalIndex": 7,
        "placeId": "ChIJtWxAZmpNFmsRlbUCkc6VtnA",
      },
    ],
}

SnappedPoints = sp["snappedPoints"]
X = []
Y = []

for i in range(len(SnappedPoints)):
    X.append(SnappedPoints[i]["location"]["latitude"])
    Y.append(SnappedPoints[i]["location"]["longitude"])
    
from matplotlib import pyplot as plt
X = np.array(X)
Y = np.array(Y)
plt.scatter(X, Y)

X = []
Y = []

for i in range(len(SnappedPoints)):
    if "originalIndex" in SnappedPoints[i]:
        X.append(SnappedPoints[i]["location"]["latitude"])
        Y.append(SnappedPoints[i]["location"]["longitude"])
X = np.array(X)
Y = np.array(Y)
plt.scatter(X, Y)

# %%
pip install matplotlib
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple/
# Collecting matplotlib
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/83/a5/d079d2287ac7a6389059a0e52537dc2e2ff342580512f42f6c7844c451a0/matplotlib-3.5.1-cp38-cp38-win_amd64.whl (7.2 MB)
# Collecting fonttools>=4.22.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/2f/85/2f6e42fb4b537b9998835410578fb1973175b81691e9a82ab6668cf64b0b/fonttools-4.33.3-py3-none-any.whl (930 kB)
# Requirement already satisfied: packaging>=20.0 in d:\python\virtualenv\neverbug\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\python\virtualenv\neverbug\lib\site-packages (from matplotlib) (2.4.7)
# Collecting cycler>=0.10
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/5c/f9/695d6bedebd747e5eb0fe8fad57b72fdf25411273a39791cde838d5a8f51/cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting kiwisolver>=1.0.1
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/97/2d/32ae1ce44d5b514dce568a809b3bed15d60ee1501b9fa9853a0fee705b59/kiwisolver-1.4.2-cp38-cp38-win_amd64.whl (55 kB)
# Requirement already satisfied: python-dateutil>=2.7 in d:\python\virtualenv\neverbug\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in d:\python\virtualenv\neverbug\lib\site-packages (from matplotlib) (7.2.0)
# Requirement already satisfied: numpy>=1.17 in d:\python\virtualenv\neverbug\lib\site-packages (from matplotlib) (1.19.4)
# Requirement already satisfied: six>=1.5 in d:\python\virtualenv\neverbug\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# Installing collected packages: fonttools, cycler, kiwisolver, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.33.3 kiwisolver-1.4.2 matplotlib-3.5.1
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'd:\python\virtualenv\neverbug\scripts\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv('ground_truth.csv')

LAT = np.array(data.iloc[:, 3])
LOG = np.array(data.iloc[:, 4])
ATI = np.array(data.iloc[:, 5])
SPD = np.array(data.iloc[:, 9])
ANG = np.array(data.iloc[:, -1])

print(LAT.shape[0])
plt.scatter(LOG, LAT, s=0.5)
plt.title('original data')
plt.ylabel('longitude')
plt.xlabel('lagtitude')
plt.show()

lat = []
log = []
ang = []
for i in range(SPD.shape[0]):
    sp = SPD[i]
    if sp != 0:
        lat.append(LAT[i])
        log.append(LOG[i])
        ang.append(ANG[i])

print(len(lat))
plt.scatter(np.array(log), np.array(lat), s=0.5)
plt.title('delete the stationary points')
plt.ylabel('longitude')
plt.xlabel('lagtitude')
plt.show()

# i = 0
# while i < len(lat):
# #     print(i, len(lat))
#     for j in range(i):
#         if abs(lat[j] - lat[i]) < 0.5/6371 and abs(log[j] - log[i]) < 0.5/6371:
#             lat.pop(i)
#             log.pop(i)
#             ang.pop(i)
#             i -= 1
#             break
#     i += 1


# print(len(lat))
# plt.scatter(np.array(log),np.array(lat), s=0.5)
# plt.title('road map data')
# plt.ylabel('longitude')
# plt.xlabel('lagtitude')
# plt.show()

class RoadSection:
    def __init__(self, lat, log, index):
        self.lat = [lat]
        self.log = [log]
        self.datapoints = len(self.lat)
        self.index = [index]
    
    def add(self, lat, log, index):
        self.lat.append(lat)
        self.log.append(log)
        self.index.append(index)


RS = [RoadSection(lat[0], log[0], 0)]
for i in range(1, len(lat)-1):
#     for j in range(i):
        if abs(ang[i+1] - ang[i]) < 15 or abs(ang[i+1] - ang[i]) > 165:
            RS[-1].add(lat[i], log[i], i)
        else:
            RS.append(RoadSection(lat[i], log[i], i))

for rs in RS:
    plt.scatter(np.array(rs.log), np.array(rs.lat), s=0.5)

plt.title('road section')
plt.ylabel('longitude')
plt.xlabel('lagtitude')
plt.show()
# Out:
# 2330
# 1610

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv('SamsungS20Ultra.csv')

LAT = np.array(data.iloc[600:1200, 3])
LOG = np.array(data.iloc[600:1200, 4])
ATI = np.array(data.iloc[600:1200, 5])
SPD = np.array(data.iloc[600:1200, 9])
ANG = np.array(data.iloc[600:1200, -1])

print(LAT.shape[0])
plt.scatter(LOG, LAT, s=0.5)
plt.title('original data')
plt.ylabel('longitude')
plt.xlabel('lagtitude')
plt.show()

lat = []
log = []
ang = []
for i in range(SPD.shape[0]):
    sp = SPD[i]
    if sp != 0:
        lat.append(LAT[i])
        log.append(LOG[i])
        ang.append(ANG[i])

print(len(lat))
plt.scatter(np.array(log), np.array(lat), s=0.5)
plt.title('delete the stationary points')
plt.ylabel('longitude')
plt.xlabel('lagtitude')
plt.show()

class RoadSection:
    def __init__(self, lat, log, index):
        self.lat = [lat]
        self.log = [log]
        self.datapoints = len(self.lat)
        self.index = [index]
    
    def add(self, lat, log, index):
        self.lat.append(lat)
        self.log.append(log)
        self.index.append(index)
        self.datapoints += 1


RS = [RoadSection(lat[0], log[0], 0)]
for i in range(1, len(lat)-1):
#     for j in range(i):
        if abs(ang[i+1] - ang[i]) < 15 or abs(ang[i+1] - ang[i]) > 165:
            RS[-1].add(lat[i], log[i], i)
        else:
            RS.append(RoadSection(lat[i], log[i], i))

for i in range(len(RS)):
    if RS[i].datapoints < 2:
        pass
    else:
        rs = RS[i]
        plt.scatter(np.array(rs.log), np.array(rs.lat), s=0.5)
        plt.title('road section')
        plt.ylabel('longitude')
        plt.xlabel('lagtitude')
        plt.show()

for i in range(len(RS)):
    if RS[i].datapoints < 2:
        pass
    else:
        rs = RS[i]
        plt.scatter(np.array(rs.log), np.array(rs.lat), s=0.5)
        plt.title('road section')
        plt.ylabel('longitude')
        plt.xlabel('lagtitude')  
plt.show()
# Out:
# 600
# 406

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv('SamsungS20Ultra.csv')

LAT = np.array(data.iloc[:, 3])
LOG = np.array(data.iloc[:, 4])
ATI = np.array(data.iloc[:, 5])
SPD = np.array(data.iloc[:, 9])
ANG = np.array(data.iloc[:, -1])

print(LAT.shape[0])
plt.scatter(LOG, LAT, s=0.5)
plt.title('original data')
plt.ylabel('longitude')
plt.xlabel('lagtitude')
plt.show()

lat = []
log = []
ang = []
for i in range(SPD.shape[0]):
    sp = SPD[i]
    if sp != 0:
        lat.append(LAT[i])
        log.append(LOG[i])
        ang.append(ANG[i])

print(len(lat))
plt.scatter(np.array(log), np.array(lat), s=0.5)
plt.title('delete the stationary points')
plt.ylabel('longitude')
plt.xlabel('lagtitude')
plt.show()

class RoadSection:
    def __init__(self, lat, log, index):
        self.lat = [lat]
        self.log = [log]
        self.datapoints = len(self.lat)
        self.index = [index]
    
    def add(self, lat, log, index):
        self.lat.append(lat)
        self.log.append(log)
        self.index.append(index)
        self.datapoints += 1


RS = [RoadSection(lat[0], log[0], 0)]
for i in range(1, len(lat)-1):
#     for j in range(i):
        if abs(ang[i+1] - ang[i]) < 15 or abs(ang[i+1] - ang[i]) > 165:
            RS[-1].add(lat[i], log[i], i)
        else:
            RS.append(RoadSection(lat[i], log[i], i))

i = 0
while i < len(RS):
    if RS[i].datapoints < 3:
        RS.pop(i)
    else:
        i += 1
print(len(RS))

for i in range(len(RS)):
    rs = RS[i]
    plt.scatter(np.array(rs.log), np.array(rs.lat), s=0.5)
    plt.title('road section')
    plt.ylabel('longitude')
    plt.xlabel('lagtitude')
    plt.show()

for i in range(len(RS)):
    rs = RS[i]
    plt.scatter(np.array(rs.log), np.array(rs.lat), s=0.5)
    plt.title('road section')
    plt.ylabel('longitude')
    plt.xlabel('lagtitude')  
plt.show()
# Out:
# 1659
# 1095
# 16
